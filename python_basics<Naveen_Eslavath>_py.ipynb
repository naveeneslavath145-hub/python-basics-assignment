# %% [markdown]
# <a href="https://colab.research.google.com/github/naveeneslavath145-hub/python-basics-assignment/blob/main/python_basics%3CNaveen_Eslavath%3E_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Naveen"
age = 27
height = 5.4
is_student = True
print(f"Name: {name} | Age: {age} | Height: {height} | Student: {is_student}")
# Out:
# Name: Naveen | Age: 27 | Height: 5.4 | Student: True

# %%
age_in_months = age*12
print("Age in months:", age_in_months)
# Out:
# Age in months: 324

# %%
age_in_days = age*365
print("Age in days:", age_in_days)
# Out:
# Age in days: 9855

# %%
reminder_age_devided_seven = age%7
print("Reminder age devided by 7:", reminder_age_devided_seven)
# Out:
# Reminder age devided by 7: 6

# %%
age_raised = age**2
print("Age raised to the power of 2:", age_raised)
# Out:
# Age raised to the power of 2: 729
